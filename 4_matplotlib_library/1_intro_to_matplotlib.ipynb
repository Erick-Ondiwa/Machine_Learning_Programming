# %% [markdown]
# # Basic Introduction
# Matplotlib is a powerful, widely-used Python library for creating static, interactive, and animated visualizations. It offers tools to make charts, graphs, and plots. Matplotlib can be used to create line plots, bar charts, scatter plots, histograms, and more, which help in analyzing and interpreting data visually.
#
# The library’s main component is pyplot, a module within Matplotlib, which provides a convenient MATLAB-like interface for plotting. You can import it as follows:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.arange(1, 6)
print(x)
# Out:
# [1 2 3 4 5]

# %%
y = np.arange(2,11,2)
print(y)
# Out:
# [ 2  4  6  8 10]

# %%
plt.plot(x,y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Basic Line Plot")
plt.show()
